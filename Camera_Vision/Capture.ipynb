# %%
import car
frame = car.capture()
car.plot(frame)
# Out:
# Instantiated a global camera object!
# Captured 1 frame.
# Plotting 1 frame...
# <PIL.Image.Image image mode=RGB size=320x240 at 0x64C74AB0>
